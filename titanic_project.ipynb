# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic.describe(include= "all")
# Out:
#              pclass     survived                  name   sex   age  \
# count   1309.000000  1309.000000                  1309  1309  1309
# unique          NaN          NaN                  1307     2    99
# top             NaN          NaN  Connolly, Miss. Kate  male     ?
# freq            NaN          NaN                     2   843   263
# mean       2.294882     0.381971                   NaN   NaN   NaN
# std        0.837836     0.486055                   NaN   NaN   NaN
# min        1.000000     0.000000                   NaN   NaN   NaN
# 25%        2.000000     0.000000                   NaN   NaN   NaN
# 50%        3.000000     0.000000                   NaN   NaN   NaN
# 75%        3.000000     1.000000                   NaN   NaN   NaN
# max        3.000000     1.000000                   NaN   NaN   NaN
#
#               sibsp        parch    ticket  fare cabin embarked  boat  body  \
# count   1309.000000  1309.000000      1309  1309  1309     1309  1309  1309
# ...

# %%
titanic["sex"].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
titanic["home.dest"].value_counts()
# Out:
# home.dest
# ?                                               564
# New York, NY                                     64
# London                                           14
# Montreal, PQ                                     10
# Paris, France                                     9
#                                                ...
# Chelsea, London                                   1
# Harrow-on-the-Hill, Middlesex                     1
# Copenhagen, Denmark                               1
# Guernsey / Montclair, NJ and/or Toledo, Ohio      1
# Antwerp, Belgium / Stanton, OH                    1
# Name: count, Length: 370, dtype: int64

# %%
titanic["sex"] == "female"
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %%
titanic["survived"] == 1
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: survived, Length: 1309, dtype: bool

# %%
# female passengers who were in first class
titanic[(titanic["sex"] == "female") & (titanic["pclass"] == 1)]
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 2         1         0                     Allison, Miss. Helen Loraine
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6         1         1                Andrews, Miss. Kornelia Theodosia
# 8         1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ..      ...       ...                                              ...
# 311       1         1       Wick, Mrs. George Dennick (Mary Hitchcock)
# 314       1         1     Widener, Mrs. George Dunton (Eleanor Elkins)
# 315       1         1                         Willard, Miss. Constance
# 319       1         1                        Wilson, Miss. Helen Alice
# 322       1         1                         Young, Miss. Marie Grice
#
#         sex age  sibsp  parch    ticket      fare    cabin embarked  boat  \
# ...

# %%
# female passengers who survived
titanic[(titanic["sex"] == "female") & (titanic["survived"] == 1)]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# ...      ...       ...                                                ...
# 1260       3         1                            Turja, Miss. Anna Sofia
# 1261       3         1                             Turkula, Mrs. (Hedwig)
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
# female passengers who survived and were in first class
titanic[(titanic["sex"] == "female") & (titanic["survived"] == 1) & (titanic["pclass"] == 1)]
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# ..      ...       ...                                                ...
# 311       1         1         Wick, Mrs. George Dennick (Mary Hitchcock)
# 314       1         1       Widener, Mrs. George Dunton (Eleanor Elkins)
# 315       1         1                           Willard, Miss. Constance
# 319       1         1                          Wilson, Miss. Helen Alice
# 322       1         1                           Young, Miss. Marie Grice
#
#         sex age  sibsp  parch    ticket      fare    cabin embarked  boat  \
# ...

# %%
# female passengers that were in first class and did not survived
titanic[(titanic["sex"] == "female") & (titanic["survived"] != 1) & (titanic["pclass"] == 1)]
# Out:
#      pclass  survived                                             name  \
# 2         1         0                     Allison, Miss. Helen Loraine
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 105       1         0                         Evans, Miss. Edith Corse
# 169       1         0                       Isham, Miss. Ann Elizabeth
# 286       1         0           Straus, Mrs. Isidor (Rosalie Ida Blun)
#
#         sex age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# 2    female   2      1      2    113781    151.55  C22 C26        S    ?    ?
# 4    female  25      1      2    113781    151.55  C22 C26        S    ?    ?
# 105  female  36      0      0  PC 17531   31.6792      A29        C    ?    ?
# 169  female  50      0      0  PC 17595   28.7125      C49        C    ?    ?
# 286  female  63      1      0  PC 17483  221.7792  C55 C57        S    ?    ?
#
#                            home.dest
# ...

# %%
titanic[titanic["age"] < "10" ]
# Out:
#       pclass  survived                                     name     sex  \
# 1          1         1           Allison, Master. Hudson Trevor    male
# 339        2         1                Becker, Master. Richard F    male
# 359        2         1            Caldwell, Master. Alden Gates    male
# 427        2         1                Hamalainen, Master. Viljo    male
# 478        2         1                    Laroche, Miss. Louise  female
# 492        2         1                    Mallet, Master. Andre    male
# 548        2         1          Richards, Master. George Sibley    male
# 590        2         1                    West, Miss. Barbara J  female
# 611        3         1                Aks, Master. Philip Frank    male
# 657        3         1                   Baclini, Miss. Eugenie  female
# 658        3         1            Baclini, Miss. Helene Barbara  female
# 747        3         0  Danbom, Master. Gilbert Sigvard Emanuel    male
# ...

# %%
# child younger than 10 yo that survived
titanic[(titanic["age"] < "10") & (titanic["survived"] == 1) ]
# Out:
#       pclass  survived                                     name     sex  \
# 1          1         1           Allison, Master. Hudson Trevor    male
# 339        2         1                Becker, Master. Richard F    male
# 359        2         1            Caldwell, Master. Alden Gates    male
# 427        2         1                Hamalainen, Master. Viljo    male
# 478        2         1                    Laroche, Miss. Louise  female
# 492        2         1                    Mallet, Master. Andre    male
# 548        2         1          Richards, Master. George Sibley    male
# 590        2         1                    West, Miss. Barbara J  female
# 611        3         1                Aks, Master. Philip Frank    male
# 657        3         1                   Baclini, Miss. Eugenie  female
# 658        3         1            Baclini, Miss. Helene Barbara  female
# 762        3         1               Dean, Master. Bertram Vere    male
# ...

# %%
# add new column to show how many relatives did every passengers have in the titanic
titanic["total_relatives"] = titanic["sibsp"] + titanic["parch"]
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# top 20 survived passengers that had the most total relatives 
titanic[titanic["survived"] == 1].sort_values("total_relatives" , ascending=False).head(20)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# 112       1         1                         Fortune, Miss. Ethel Flora
# 113       1         1                         Fortune, Miss. Mabel Helen
# 116       1         1                Fortune, Mrs. Mark (Mary McDougald)
# 550       2         1              Richards, Mrs. Sidney (Emily Hocking)
# 249       1         1                        Ryerson, Master. John Borie
# 449       2         1              Hocking, Mrs. Elizabeth (Eliza Needs)
# 253       1         1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# ...

# %%
# top 20 not survived passengers that had the most total relatives 
titanic[titanic["survived"] == 0].sort_values("total_relatives" , ascending=False).head(20)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1171       3         0              Sage, Master. William Henry    male  14.5
# 1170       3         0               Sage, Master. Thomas Henry    male     ?
# 1172       3         0                          Sage, Miss. Ada  female     ?
# 1173       3         0             Sage, Miss. Constance Gladys  female     ?
# 1174       3         0        Sage, Miss. Dorothy Edith 'Dolly'  female     ?
# 1175       3         0                  Sage, Miss. Stella Anna  female     ?
# 1180       3         0           Sage, Mrs. John (Annie Bullen)  female     ?
# 1176       3         0                 Sage, Mr. Douglas Bullen    male     ?
# 1177       3         0                      Sage, Mr. Frederick    male     ?
# 1178       3         0                 Sage, Mr. George John Jr    male     ?
# 1179       3         0                    Sage, Mr. John George    male     ?
# ...

# %%
# all the passengers that traveled alone by titanic
titanic[titanic["total_relatives"] == 0]
# Out:
#       pclass  survived                           name     sex   age  sibsp  \
# 0          1         1  Allen, Miss. Elisabeth Walton  female    29      0
# 5          1         1            Anderson, Mr. Harry    male    48      0
# 7          1         0         Andrews, Mr. Thomas Jr    male    39      0
# 9          1         0        Artagaveytia, Mr. Ramon    male    71      0
# 12         1         1  Aubart, Mme. Leontine Pauline  female    24      0
# ...      ...       ...                            ...     ...   ...    ...
# 1302       3         0              Yousif, Mr. Wazli    male     ?      0
# 1303       3         0          Yousseff, Mr. Gerious    male     ?      0
# 1306       3         0      Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0            Zakarian, Mr. Ortin    male    27      0
# 1308       3         0             Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
# how many of alone passengers were men or women?
titanic[titanic["total_relatives"] == 0].value_counts("sex")
# Out:
# sex
# male      596
# female    194
# Name: count, dtype: int64

# %%
# how many of alone passengers survived or died?
titanic[titanic["total_relatives"] == 0].value_counts("survived")
# Out:
# survived
# 0    551
# 1    239
# Name: count, dtype: int64

# %%
# survived male that traveled alone
titanic[(titanic["total_relatives"] == 0)  & (titanic["sex"] == "male") & (titanic["survived"] == 1)]
# Out:
#       pclass  survived                                       name   sex age  \
# 5          1         1                        Anderson, Mr. Harry  male  48
# 14         1         1       Barkworth, Mr. Algernon Henry Wilson  male  80
# 22         1         1                      Behr, Mr. Karl Howell  male  26
# 29         1         1  Bjornstrom-Steffansson, Mr. Mauritz Hakan  male  28
# 31         1         1                           Blank, Mr. Henry  male  40
# ...      ...       ...                                        ...   ...  ..
# 1233       3         1                  Sundman, Mr. Johan Julian  male  44
# 1236       3         1                 Svensson, Mr. Johan Cervin  male  14
# 1238       3         1                 Tenglin, Mr. Gunnar Isidor  male  25
# 1254       3         1               Tornquist, Mr. William Henry  male  25
# 1277       3         1                       Vartanian, Mr. David  male  22
#
# ...

# %%
# survived female that traveled alone
titanic[(titanic["total_relatives"] == 0)  & (titanic["sex"] == "female") & (titanic["survived"] == 1)]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 12         1         1                    Aubart, Mme. Leontine Pauline
# 13         1         1                     Barber, Miss. Ellen 'Nellie'
# 18         1         1                            Bazzani, Miss. Albina
# 23         1         1                            Bidois, Miss. Rosalie
# ...      ...       ...                                              ...
# 1216       3         1                               Smyth, Miss. Julia
# 1223       3         1                  Stanley, Miss. Amy Zillah Elsie
# 1260       3         1                          Turja, Miss. Anna Sofia
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
#
#          sex age  sibsp  parch    ticket      fare cabin embarked boat body  \
# ...
